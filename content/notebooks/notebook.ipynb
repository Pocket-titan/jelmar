# %%
# ---
# date: 2023-12-04
# image: ../images/icon.png
# ---

# %% [markdown]
# # Title
#
# normal text
#
# In theory, now our code blocks should also be cool?
#
#
# ```py
# def funcy(x):
#   return x
# ```
#
# math??
#
#
# $$
# 1 + 2 = 3
# $$

# %%
import matplotlib.pyplot as plt

def funcy(x: int, y: str) -> list[str]:
    print("hello!", x)
    obj = {
        "a": 1,
    };
    obj["b"] = 2

plt.show() # this is a comment!

for i in range(1000):
    print(i)

class Wow(int):
    def __init__(self, arg: int, x: None = None) -> None:
        return None
    
funcy(5, "omg")

# %%
# empty

# %%
# hide
def test():
    assert True

# %%
# hide
print("what")

# %%
# fold
print("hello world")

# %%
def test2():
    assert True

# %%
def wow():
    print("omg")

# %% [markdown]
# More markdown
#
# ## Two
#
# ### Three
#
# #### Four
